# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Yohana Beatrice Nainggolan
# - **Email:** yohanabeatrice1263@gmail.com
# - **ID Dicoding:** yohanabeatrice

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana demografi pelanggan yang dimiliki oleh perusahaan? #customer_dataset.csv
# - Pertanyaan 2: Bagaimana performa penjualan perusahaan dalam beberapa waktu belakangan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# melakukan import data yang telah disimpan di dalam google drive sebelumnya. data yang digunakan : customers_dataset.csv, order_items_dataset.csv, dan orders_dataset.csv

# %%
! gdown --id 1Wi0LvA0vDuuMfGjQN5RzBS_p04S_UO6s
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Wi0LvA0vDuuMfGjQN5RzBS_p04S_UO6s
# To: /content/customers_dataset.csv
# 100% 9.03M/9.03M [00:00<00:00, 43.5MB/s]

# %%
! gdown --id 1bAKTXu7dTp_C9wRk0oKKeR861-HTokqb
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1bAKTXu7dTp_C9wRk0oKKeR861-HTokqb
# To: /content/order_items_dataset.csv
# 100% 15.4M/15.4M [00:00<00:00, 69.1MB/s]

# %%
! gdown --id 1XA-VOljP_2XG3f1YYEPKK41kgXfAwFeO
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1XA-VOljP_2XG3f1YYEPKK41kgXfAwFeO
# To: /content/orders_dataset.csv
# 100% 17.7M/17.7M [00:00<00:00, 58.8MB/s]

# %%
# !ls
# Out:
# all_data.csv  customers_dataset.csv  order_items_dataset.csv  orders_dataset.csv  sample_data

# %%
customer_dataset = pd.read_csv("customers_dataset.csv")

# %%
order_item = pd.read_csv("order_items_dataset.csv")

# %%
orders = pd.read_csv("orders_dataset.csv")

# %%
customer_dataset.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
order_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ### Assessing Data

# %%
#memeriksa informasi terkait dataset yang digunakan
customer_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
#mengubah kolom order_approved_at dan order_delivered_carrier_date yang sebelumnya masih bertipe object menjadi datetime
datetime_columns = ["order_approved_at", "order_delivered_carrier_date"]

for column in datetime_columns:
  orders[column] = pd.to_datetime(orders[column])

# %%
#memeriksa adanya kolom yang terdapat bagian kosong
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", orders.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customer_dataset.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
order_item.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
orders.describe()
# Out:
# <ipython-input-218-ce468bcbb7ec>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders.describe()
# <ipython-input-218-ce468bcbb7ec>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders.describe()
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...

# %%
round(100*(customer_dataset.isnull().sum()/len(customer_dataset)), 2).sort_values(ascending=False)
# Out:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64

# %%
round(100*(order_item.isnull().sum()/len(order_item)), 2).sort_values(ascending=False)
# Out:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64

# %%
print("Jumlah duplikasi: ",customer_dataset.duplicated().sum())
customer_dataset.describe()
# Out:
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
print("Jumlah duplikasi: ",order_item.duplicated().sum())
order_item.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Cleaning Data

# %%
customer_dataset.drop_duplicates(inplace=True)

# %%
#memeriksa apabila terdapat duplikasi data
print("Jumlah duplikasi: ", customer_dataset.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customer_dataset[customer_dataset.customer_state.isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
order_item[order_item.product_id.isna()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
#melakukan drop pada data yang terdapat bagian yang kosong
orders.dropna(axis=0, inplace=True)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  object
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  object
#  7   order_estimated_delivery_date  96461 non-null  object
# dtypes: datetime64[ns](2), object(6)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data customer_dataset

# %%
customer_dataset.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customer_dataset.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customer_dataset.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore Data order_item

# %%
order_item.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# ###Explore Data orders

# %%
orders.describe(include="all")
# Out:
# <ipython-input-233-53760f63e7b4>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders.describe(include="all")
# <ipython-input-233-53760f63e7b4>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders.describe(include="all")
#                                 order_id                       customer_id  \
# count                              96461                             96461
# unique                             96461                             96461
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...

# %%
order_detail = pd.merge(
    left=orders,
    right=order_item,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_detail.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
all_df = pd.merge(
    left=customer_dataset,
    right=order_detail,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
all_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
all_df.groupby(by=["customer_city", "product_id"]).agg({
    "price": "sum",
})
# Out:
#                                                        price
# customer_city       product_id
# abadia dos dourados 1081ae52311daac87fb54ba8ce4670ac  120.00
#                     418d480693f2f01e9cf4568db0346d28  199.00
#                     c1aabbb6f4caec9f5bf7cd80519d6cc0   39.90
# abadiania           0a9b9a871ffaec6c0198334558a6c6a1  949.99
# abaete              3354a4e684f5e7199f9407db70ccd92b   85.99
# ...                                                      ...
# ze doca             2942938c3d7cfb0161ad93b80cd60b01   65.00
#                     36ea81e90d1292dcdc3ad8abb09c20fe   74.80
#                     926d11f0e2a1171fed968faf5caa8f92   39.90
# zortea              dd47440cb56de3ab674f9208ff0edc3e   69.90
#                     de6702c748c719cbd13bb814f006ba22   29.90
#
# [87506 rows x 1 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana demografi pelanggan yang dimiliki oleh perusahaan?

# %%
bystate_df = all_df.groupby(by="customer_city").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

# 10 state dengan tingkat penjualan tertinggi
top_10_states = bystate_df.sort_values(by="customer_count", ascending=False).head(10)

plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="customer_city",
    data=top_10_states,
    palette=colors_
)
plt.title("Number of Customer by States (Top 10)", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-237-b62de1740cea>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-237-b62de1740cea>:11: UserWarning:
# The palette list has fewer values (8) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 2: Bagaimana performa penjualan perusahaan dalam beberapa waktu belakangan?

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
    "price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
#   order_approved_at  order_count    revenue
# 0           2016-09            1     134.97
# 1           2016-10          270   40941.30
# 2           2016-11            0       0.00
# 3           2016-12            1      10.90
# 4           2017-01          715  106888.10

# %%
plt.figure(figsize=(10, 5))

#membuat bar plot
plt.bar(monthly_orders_df["order_approved_at"], monthly_orders_df["order_count"], color="#72BCD4", alpha=0.7)

for i, value in enumerate(monthly_orders_df["order_count"]):
    plt.text(monthly_orders_df["order_approved_at"].iloc[i], value + 50, str(value), ha='center', va='bottom', fontsize=8)

plt.xticks(monthly_orders_df["order_approved_at"], monthly_orders_df["order_approved_at"], rotation=45, ha='right', fontsize=10)

# menambah label dan detail
plt.xlabel("Month", fontsize=12)
plt.ylabel("Number of Orders", fontsize=12)
plt.title("Number of Orders per Month", loc="center", fontsize=20)

# menambah grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
#mengecek produk yang paling banyak dan sedikit terjual
product_sales = all_df.groupby('product_id')['order_item_id'].count().reset_index(name='total_sales')

most_sold_product = product_sales.loc[product_sales['total_sales'].idxmax()]
least_sold_product = product_sales.loc[product_sales['total_sales'].idxmin()]

print(f"The product with the most sales is {most_sold_product['product_id']} with {most_sold_product['total_sales']} sales.")
print(f"The product with the lowest sales is {least_sold_product['product_id']} with {least_sold_product['total_sales']} sales.")
# Out:
# The product with the most sales is aca2eb7d00ea1a7b8ebd4e68314663af with 520 sales.
# The product with the lowest sales is 00066f42aeeb9f3007548bb9d3f33c38 with 1 sales.

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1: Berdasarkan demografi, dari seluruh kota asal customer, didapatkan hasil bahwa 10 kota dengan tingkat penjualan tertinggi adalah san paulo, rio de janiero, belo harizonte. brasilia, curitiba, campinas, portoo alegre, salvador, guarulhos, san bernardo da campo.
# - Conclution pertanyaan 2: Berdasarkan data dan hasil visualisasi, didapatkan hasil bahwa performa penjualan dalam beberapa waktu belakangan, bulan dengan penjualan tertinggi adalah pada bulan 11 tahun 2017. Produk dengan penjualan tertinggi adalah produk dengan kode aca2eb7d00ea1a7b8ebd4e68314663af dengan penjualan sebanyak 520 dan yang terendah adalah produk dengan id 00066f42aeeb9f3007548bb9d3f33c38 dengan banyak penjualan 1.
